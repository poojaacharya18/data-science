# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
from pandas import DataFrame

# %%
pj=pd.read_csv('/content/drive/MyDrive/principle of data science lab/jacp.txt')
pj.head()
# Out:
#   ptid mridate age male race weight height  packyrs yrsquit   alcoh physact chf chd stroke  diabet genhlth ldl alb crt plt    sbp    aai    fev dsst atrophy whgrd numinf   volinf obstime death
# 0    1  120791  72    1    2  173.0  169.0  54.00...
# 1    2   90192  81    0    2  139.0  170.0   0.00...
# 2    3   82092  90    1    2  145.0  170.0   0.00...
# 3    4   73192  72    1    1  190.0  181.0  33.00...
# 4    5  111691  70    0    1  153.0  158.5   0.00...

# %%
pj=pd.read_json('/content/drive/MyDrive/shoulder (1).json')
pj
# Out:
#       id  trt  sex  age  pain  time
# 0    101    1    2   64     0     1
# 1    101    1    2   64     0     2
# 2    101    1    2   64     0     3
# 3    101    1    2   64     0     4
# 4    101    1    2   64     0     5
# ..   ...  ...  ...  ...   ...   ...
# 241  219    2    1   61     2     2
# 242  219    2    1   61     2     3
# 243  219    2    1   61     2     4
# 244  219    2    1   61     1     5
# 245  219    2    1   61     0     6
#
# [246 rows x 6 columns]

# %%
import librosa
y, sr = librosa.load('/content/gdrive/MyDrive/principle of data science lab/song1.mp3')

# %%
import os
import numpy as np
import librosa
import pandas as pd


def print_plot_play(x, Fs, text=''):

    #print('%s Fs = %d, x.shape = %s, x.dtype = %s' % (text, Fs, x.shape, x.dtype))
    ipd.display(ipd.Audio(data=x, rate=Fs))


# Read mp3
fn_mp3 = os.path.join('..', 'data', 'B', '/content/gdrive/MyDrive/principle of data science lab/song1.mp3')
x, Fs = librosa.load(fn_mp3, sr=None)
print_plot_play(x=x, Fs=Fs, text='MP3 file: ')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
